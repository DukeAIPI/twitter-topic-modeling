# %%
import numpy as np
import pandas as pd
import os
from searchtweets import load_credentials, gen_request_parameters, collect_results

# %%
def get_tweets(term):
    credentials = load_credentials(env_overwrite=True)
    query = gen_request_parameters(f"{term} -is:retweet -is:reply lang:en", results_per_call=100, granularity=None)
    tweets = collect_results(query, max_tweets = 1000, result_stream_args=credentials)
    return tweets

def convert_to_df(messy_tweets):
    '''Turns messy json repsonse from get_tweets into a clean df.
    
    Args:
        messy_tweets (list of dicts extracted from json response): 'data' part of .json() parse
        
    Returns:
        df: df that has the extracted tweets
    '''
    clean = []
    
    for i in range(len(messy_tweets)):
        for j in range(len(messy_tweets[i]['data'])):
            clean.append(messy_tweets[i]['data'][j]['text'])
    
    df = pd.DataFrame(clean, columns = ['tweet'])
    df = df.drop_duplicates(ignore_index = True)
    return df

# %%
messy_tweets = get_tweets("Biden")
tweets = convert_to_df(messy_tweets)
tweets
# Out:
# cannot read file ~/.twitter_keys.yaml
# Error parsing YAML file; searching for valid environment variables
#                                                  tweet
# 0    Biden flips the switch on Trump's incandescent...
# 1    Jen Psaki has no information that Joe Biden ev...
# 2    Joe Biden still hasn’t tear-gassed a church pa...
# 3    Forced Masking Ruled Unconstitutional: Biden P...
# 4    How Biden Can Halt the U.S. Postal Service’s G...
# ..                                                 ...
# 992                           ‘Joe Biden’ is an actor.
# 993  Once again, I just really want to thank the 80...
# 994  Biden and Obama are responsible for the deaths...
# 995  GOP Planning To Launch Impeachment Of DHS Secr...
# 996  "It’s time for Washington to do its part. Secu...
#
# [997 rows x 1 columns]

# %% [markdown]
# # Clean tweets

# %%
import nltk
from nltk.corpus import stopwords
import string 
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
punctuations = string.punctuation
wordnet_lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/leocorelli/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/leocorelli/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/leocorelli/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
test_tweets = tweets.copy()

# %%
test_tweets["tweet"] = test_tweets["tweet"].apply(lambda x: ' '.join(wordnet_lemmatizer.lemmatize(word).lower().strip() for word in x.split() if word.lower() not in stop_words and word[0]!="@" and word[:5]!="https"))
test_tweets
# Out:
#                                                  tweet
# 0    biden flip switch trump's incandescent light b...
# 1    jen psaki information joe biden ever spoke hun...
# 2    joe biden still hasn’t tear-gassed church park...
# 3    forced masking ruled unconstitutional: biden p...
# 4    biden halt u.s. postal service’s gas-guzzling ...
# ..                                                 ...
# 992                                 ‘joe biden’ actor.
# 993  again, really want thank 80,000 voter maine vo...
# 994  biden obama responsible death seal team 6 exto...
# 995  gop planning launch impeachment dhs secretary ...
# 996  "it’s time washington part. secure border." #a...
#
# [997 rows x 1 columns]

# %% [markdown]
# # Bertopic

# %%
from bertopic import BERTopic

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(test_tweets["tweet"])

# %%
info = topic_model.get_topic_info()

# %%
test_df = pd.concat([tweets["tweet"], test_tweets["tweet"]],axis=1)
test_df.columns = ["original_tweet","cleaned_tweet"]
test_df
# Out:
#                                         original_tweet  \
# 0    Biden flips the switch on Trump's incandescent...
# 1    Jen Psaki has no information that Joe Biden ev...
# 2    Joe Biden still hasn’t tear-gassed a church pa...
# 3    Forced Masking Ruled Unconstitutional: Biden P...
# 4    How Biden Can Halt the U.S. Postal Service’s G...
# ..                                                 ...
# 992                           ‘Joe Biden’ is an actor.
# 993  Once again, I just really want to thank the 80...
# 994  Biden and Obama are responsible for the deaths...
# 995  GOP Planning To Launch Impeachment Of DHS Secr...
# 996  "It’s time for Washington to do its part. Secu...
#
#                                          cleaned_tweet
# 0    biden flip switch trump's incandescent light b...
# 1    jen psaki information joe biden ever spoke hun...
# 2    joe biden still hasn’t tear-gassed church park...
# 3    forced masking ruled unconstitutional: biden p...
# 4    biden halt u.s. postal service’s gas-guzzling ...
# ..                                                 ...
# 992                                 ‘joe biden’ actor.
# 993  again, really want thank 80,000 voter maine vo...
# 994  biden obama responsible death seal team 6 exto...
# 995  gop planning launch impeachment dhs secretary ...
# 996  "it’s time washington part. secure border." #a...
#
# [997 rows x 2 columns]

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                       Name
# 0      -1    214                  -1_biden_president_us_amp
# 1       0    164                0_biden_election_trump_2020
# 2       1     75                 1_joe_biden_fuck_supporter
# 3       2     71              2_laptop_story_twitter_hunter
# 4       3     50      3_income_unexplained_reveal_financial
# 5       4     38              4_student_loan_debt_canceling
# 6       5     34                    5_ha_garland_old_beings
# 7       6     31                6_ukraine_russia_putin_nato
# 8       7     30        7_border_illegal_immigration_bidens
# 9       8     29             8_partner_business_white_house
# 10      9     26                  9_gas_drilling_oil_policy
# 11     10     25             10_pardon_sentence_first_agent
# 12     11     23           11_hunter_hunterbiden_biden_baby
# 13     12     22           12_judge_supreme_court_sabotaged
# 14     13     20    13_tax_corporations_inflation_americans
# 15     14     18       14_light_incandescent_bulb_lightbulb
# 16     15     17         15_squad_adviser_sorosfunded_group
# 17     16     17  16_treatment_access_administration_expand
# 18     17     16               17_manchin_inside_fears_wont
# 19     18     15                 18_paul_rand_pushed_soviet
# 20     19     14                       19_dr_jill_doctor_oz
# 21     20     13               20_upgrade_opinion_huge_show
# 22     21     12             21_positive_contact_close_test
# 23     22     12            22_kamala_harris_speaker_pelosi
# 24     23     11           23_vaccine_work_ivermectin_covid

# %%
topic_model.get_representative_docs()
# Out:
# {14: ['biden administration phase inefficient lightbulb championed trump via',
#   'biden administration phase inefficient lightbulb championed trump via',
#   "funny article claim manufacturer want make sell incandescent light bulb &amp; consumer really want buy bulbs. true, federal gov. (@potus biden's need make rule?"],
#  8: ['joe biden met hunter biden business partner white house via',
#   'white house visitor logs reveal meetings hunter biden business partner joe biden',
#   'hunter biden business partner made 8 additional white house visit 2016, visitor log show'],
#  1: ['wanna see joe biden smoke weed', 'fuck joe biden', 'fuck joe biden'],
#  9: ['gasoline price high enough.',
#   'report, u.s. gas exports triple u.s. gas production, low gas reserves sends prices soaring - biden effect!',
#   'thanx 2 biden! $58 year ago...not tank gas.'],
#  5: ["anyone ever think garland would ever investigate hunter biden joe biden that's attorney general evil president joe biden son hunter. remember twitter calling russian disinformation.",
#   'attorney general merrick garland say need special counsel hunter biden probe.',
#   'don’t wish biden would made difference choice attorney general? someone unafraid prosecute seditionists.'],
#  13: ['tell truth #lyingwhitmer $b funding b/c lottery sale covid? printed devaluation dollar gift friends biden? trump tax cut resulted much higher tax revenues? 2021 single highest tax revenue ever?',
#   'biden fooling americans. biden tax corporations highest rate ever, corporations choice pas tax consumer form price hikes. inflation tax biden passing every taxpayer',
#   'biden fooling americans. biden tax corporations highest rate ever, corporations choice pas tax consumer form price hikes. inflation tax biden passing every single taxpayer'],
#  3: ["president biden's financial record reveal $5.2 million undisclosed income",
#   'financial record reveal biden $5.2million unexplained income via',
#   'joe biden claimed never involved hunter’s business dealing yet paid 700k legal bill deal communist china. joe also can’t explain $5.2m income.'],
#  2: ['censorship? damage done twitter sold perfect time?',
#   "elon musk call twitter's hunter biden laptop censorship 'incredibly inappropriate' | washington examiner",
#   "need put lawsuit hunter biden's laptop. fox broadcast nothing else. via"],
#  20: ['opinion | biden show huge upgrade trump - washington post',
#   'opinion | biden show huge upgrade trump',
#   'biden’s approval slump coast-to-coast concern rise performance, fitness - -'],
#  4: ['president biden forgive student loan debt?',
#   'breaking: desperate biden looking option forgive federal student loan debt time election -',
#   'biden forgives student loan promise won’t ever publicly make fun again. least maybe little less. probably'],
#  10: ['full list people joe biden pardoned',
#   '#biden audacity pardon hunter?',
#   'biden issues first pardons presidency'],
#  11: ['big guy trouble... know yet 😂😂😂 #hunterbiden #biden',
#   'hunter biden selfie got crying.',
#   'hunter biden hot mess huge hog he’s actually based.'],
#  0: ['kathy griffin many followers? legit question. fake like biden voters?',
#   'biden stole presidency, election fraud saw happen. legitimate government. thank elon letting speak!',
#   'joe biden looney left solution assault southern boarder except make democrats. dnc want number democrat switching parties. want come, rapist , drug smugglers, cartel members, gang member'],
#  18: ["rand paul claim biden pushed putin invade 'soviet union' country via",
#   'rand paul claim biden pushed putin invading ‘soviet union’ state tense hearing blinken',
#   'rand paul claims biden pushed putin tense hearing blinken invade ‘soviet union’ state'],
#  16: ['biden administration seek expand access treatment amid opioid epidemic read more: #opioidcrisis #opioids #biden #politics #administration #government #addiction',
#   'encouraging news fight covid-19, new treatment kid 12 approved fda. come biden administration announces plan make another effective treatment adult accessible.',
#   'beltway insider: biden/earth day, ukraine war, macron wins, covid/vaccine totals, queen elizabeth, orrin hatch'],
#  15: ["fox news (https://t.co/i272dv0xz9): secretive soros-funded group work behind scene biden admin policy, document show governing impact's internal memo say implemented 20 federal agenda item",
#   'cedric richmond, biden senior adviser, leave white house dnc',
#   'union pacific participant wefs global redesign initiative (nwo agenda 21/2030) soro\'s osi "us termination project"? looks highly suspicious:'],
#  7: ['hear ainsworth back ivey sending troop border: ‘biden hasn’t protected border’',
#   "this.....and guarantee republican win november. sick illegals flooding country. biden's border plan let everyone -- hide public via",
#   "biden's border plan let everyone hide public"],
#  17: ["senator manchin, january 6.? manchin open door striking climate deal gop backing watered-down version biden's big bill via",
#   "joe manchin say support biden's key spending plan form.",
#   "joe blows joe manchin shuts door supporting biden's social plan like universal pre-k affordable childcare"],
#  6: ["surrender monkeys! maybe nazi scum control ukraine stupid thought were. biden crime family set lose billion ukraine fall putin. let's go putin!",
#   'president biden preventing wwiii tat commie friend putin russia trying instagate. priority',
#   'russia &amp; united states dump life sentenced prisoner deserted island #russia #russiaukrainewar #putin #biden #usa'],
#  23: ['biden president!!!! trump 2020!!! covid seasonal flu. democrats legitimately election since 2000. entire us government corrupt',
#   'love solidarity vp president. one get covid, literally doesn’t matter don’t work together all. hell, i’m convinced work all. mean, kamala openly called joe biden racist national television two year ago',
#   'joe biden kamala joke, incompetent election rigged. ivermectin work covid vaccine killing people. said it!!'],
#  19: ['fake medium fall jill biden calling dr. refuse call mr oz dr. well jill fake.',
#   'anyine see newsmax? regarding dr oz dr jill.. medium flipped dr oz medical degree insist titling mr. prop jill biden titled dr! seriously far hugest joke discus real issues???',
#   'dr. oz, trumps jill biden'],
#  21: ['kamala harris test positive covid vice president isolates symptom – joe biden close contact',
#   'kamala harris test positive covid vice president isolates symptom – joe biden close contact',
#   'kamala harris test positive covid vice president isolates symptom – joe biden close contact'],
#  22: ['fighting nothing? biden harris resign tonight! baruch 3:28 “but destroyed, wisdom, perished foolishness.”',
#   "biden get removed, mark becomes speaker we'll kamala (a pawn) president mark (establishment) vp prolly cheney speaker. either way... we're screwed still. please people remember vote 2024. stop voting swamp creatures.",
#   'kamala harris really need sitting next biden elderly politician working white house right now.'],
#  12: ['supreme court seems fed trump judge sabotaged biden #smartnews',
#   'supreme court seems fed trump judge sabotaged biden via',
#   'supreme court seems fed trump judge sabotaged biden']}

# %%
def get_clusters(info):
    
    clusters = info.copy()
    clusters.sort_values(by="Topic")
    
    
    clusters["clean_clusters"] = 0
    
    for i in range(clusters.shape[0]):
        clusters["clean_clusters"].loc[i] = clusters["Name"].loc[i].split("_")[1:]
        
    clusters = clusters[clusters["Topic"]!=-1] # remove unclustered items
    clusters = clusters.reset_index(drop=True)
    
    return clusters

# %%
this = get_clusters(info)
this
# Out:
#     Topic  Count                                         Name  \
# 0       0     71                        0_biden_is_great_good
# 1       1     70                  1_pardon_man_clemency_first
# 2       2     69  2_border_illegal_immigration_administration
# 3       3     69                  3_ukraine_war_putin_climate
# 4       4     64                   4_student_debt_loan_cancel
# 5       5     62                 5_twitter_musk_elon_censored
# 6       6     55                        6_joe_biden_fuck_like
# 7       7     37        7_unexplained_income_financial_reveal
# 8       8     34               8_harris_kamala_close_positive
# 9       9     33              9_covid_vaccine_covid19_funding
# 10     10     33              10_partner_business_white_house
# 11     11     31               11_inflation_tax_schumer_taxes
# 12     12     29                  12_energy_oil_land_drilling
# 13     13     28                13_laptop_hunter_hacked_story
# 14     14     25         14_hunter_crackhead_hunters_dealings
# 15     15     24      15_garland_investigation_counsel_refuse
# 16     16     17                    16_hiv_widow_brothers_get
# 17     17     16                 17_fed_judge_sabotaged_seems
# 18     18     12                    18_election_amp_of_stolen
# 19     19     12                  19_fuck_2024_party_election
#
#                                     clean_clusters
# 0                         [biden, is, great, good]
# 1                   [pardon, man, clemency, first]
# 2   [border, illegal, immigration, administration]
# 3                   [ukraine, war, putin, climate]
# 4                    [student, debt, loan, cancel]
# 5                  [twitter, musk, elon, censored]
# 6                         [joe, biden, fuck, like]
# 7         [unexplained, income, financial, reveal]
# 8                [harris, kamala, close, positive]
# 9               [covid, vaccine, covid19, funding]
# 10               [partner, business, white, house]
# 11                [inflation, tax, schumer, taxes]
# 12                   [energy, oil, land, drilling]
# 13                 [laptop, hunter, hacked, story]
# 14          [hunter, crackhead, hunters, dealings]
# 15       [garland, investigation, counsel, refuse]
# 16                     [hiv, widow, brothers, get]
# 17                  [fed, judge, sabotaged, seems]
# 18                     [election, amp, of, stolen]
# 19                   [fuck, 2024, party, election]
